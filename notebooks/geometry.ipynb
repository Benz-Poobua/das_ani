# %% [markdown]
# ### DAS Geometry

# %%
# Import necessary dependencies
import os
import folium
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define paths
file_path = os.path.join('..', 'geometry', 'geometry_offset.csv')

# %%
# Read CSV data
das_fiber_all = pd.read_csv(file_path)
das_fiber_all = das_fiber_all.drop(das_fiber_all.columns[0], axis=1)
das_fiber_all
# Out:
#       ch        long        lat
# 0    399 -122.181048  37.435539
# 1    400 -122.181101  37.435501
# 2    401 -122.181166  37.435452
# 3    402 -122.181247  37.435391
# 4    403 -122.181307  37.435347
# ..   ...         ...        ...
# 346  745 -122.205771  37.421297
# 347  746 -122.205873  37.421284
# 348  747 -122.205963  37.421272
# 349  748 -122.206011  37.421266
# 350  749 -122.206119  37.421252
#
# [351 rows x 3 columns]

# %%
# Compute center of map
center_lat = das_fiber_all['lat'].mean()
center_lon = das_fiber_all['long'].mean()

# Create folium map
m = folium.Map(location=[center_lat, center_lon], zoom_start=15, tiles='OpenStreetMap')

# Add channel markers
for _, row in das_fiber_all.iterrows():
    folium.CircleMarker(
        location=[row['lat'], row['long']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        popup=f"Ch: {row['ch']}"
    ).add_to(m)


# Connect channels with a red line (fiber path)
folium.PolyLine(
    das_fiber_all[['lat', 'long']].values.tolist(),
    color='red',
    weight=2,
    opacity=0.8
).add_to(m)

# Add layer control (optional)
folium.LayerControl().add_to(m)

# Display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53ff9ec1d89087e427d58069cb8304f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53ff9ec1d89087e427d58069cb8304f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53ff9ec1d89087e427d58069cb8304f2 = L.map(
#                 &quot;map_53ff9ec1d89087e427d58069cb8304f2&quot;,
#                 {
#                     center: [37.42708544327008, -122.19267589619089],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_295be05f140fecc414dfe3d6875ee9d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_295be05f140fecc414dfe3d6875ee9d6.addTo(map_53ff9ec1d89087e427d58069cb8304f2);
#
#
#             var circle_marker_05b93f995a9c3c84bf7e1e8ef8061b00 = L.circleMarker(
#                 [37.4355392208, -122.181048434],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53ff9ec1d89087e427d58069cb8304f2);
#
#
#         var popup_88391edca6be88df53e0bd52fd5f7e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d63765465bdfaf477d3c0d7c26793d38 = $(`&lt;div id=&quot;html_d63765465bdfaf477d3c0d7c26793d38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 399.0&lt;/div&gt;`)[0];
#                 popup_88391edca6be88df53e0bd52fd5f7e80.setContent(html_d63765465bdfaf477d3c0d7c26793d38);
#
#
#
#         circle_marker_05b93f995a9c3c84bf7e1e8ef8061b00.bindPopup(popup_88391edca6be88df53e0bd52fd5f7e80)
#         ;
#
#
#
#
#             var circle_marker_864c89e86edcdccef52383c39ca23ff3 = L.circleMarker(
#                 [37.4355009044, -122.181100863],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53ff9ec1d89087e427d58069cb8304f2);
#
#
#         var popup_282ecdf0487be4be0e94a3383e3acccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_714bb203bd5b5d78f5332988227a3741 = $(`&lt;div id=&quot;html_714bb203bd5b5d78f5332988227a3741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 400.0&lt;/div&gt;`)[0];
#                 popup_282ecdf0487be4be0e94a3383e3acccc.setContent(html_714bb203bd5b5d78f5332988227a3741);
#
#
#
#         circle_marker_864c89e86edcdccef52383c39ca23ff3.bindPopup(popup_282ecdf0487be4be0e94a3383e3acccc)
#         ;
#
#
#
#
#             var circle_marker_ad1fc3cbae5621555b9c90c9820cb687 = L.circleMarker(
#                 [37.4354516739, -122.181166216],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_53ff9ec1d89087e427d58069cb8304f2);
#
#
#         var popup_367d6aa9b153478ea1576c2ce6445abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8983526fcfcce6296d5689bdd81dad90 = $(`&lt;div id=&quot;html_8983526fcfcce6296d5689bdd81dad90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ch: 401.0&lt;/div&gt;`)[0];
#                 popup_367d6aa9b153478ea1576c2ce6445abb.setContent(html_8983526fcfcce6296d5689bdd81dad90);
#
#
#
#         circle_marker_ad1fc3cbae5621555b9c90c9820cb687.bindPopup(popup_367d6aa9b153478ea1576c2ce6445abb)
#         ;
#
#
#
#
#             var circle_marker_42cf1ca2c93200
